# %% [markdown]
# ## Import and Load data file

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import csv

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('query.json').read()
intents = json.loads(data_file)
intents
# Out:
# {'intents': [{'tag': 'greeting',
#    'query_templates': ['Hi', 'Hello', 'Hey'],
#    'response_templates': ['Hello!',
#     'Hi there!',
#     'Hey! How can I assist you today?']},
#   {'tag': 'product_inquiry',
#    'query_templates': ['Tell me about [product_name]',
#     'What can you tell me about [product_name]?',
#     'I want to learn more about [product_name]',
#     '[product_name]'],
#    'response_templates': ["Sure, {product_name} is a {type}. It's priced at {product_real_price} and currently in stock.",
#     "I'd be happy to help with {product_name}. The author of the book is {author}. The price is {product_real_price}."]},
#   {'tag': 'author_inquiry',
#    'query_templates': ['Tell me about [author]',
#     'What can you tell me about [author]?',
#     'What books have been published by the [author]?',
#     '[author]'],
#    'response_templates': ['Sure, {author} has published {product_name}.',
#     "I'd be happy to help with. The books by the {author} are {product_name}."]},
#   {'tag': 'goodbye',
#    'query_templates': ['Goodbye', 'See you later', 'Bye'],
#    'response_templates': ['Goodbye!',
#     'See you later!',
#     'Bye, have a great day!']}]}

# %%
product_data=[]

with open('books_from_ecom.csv', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        product_data.append(row)    
product_data
# Out:
# [{'sr_no': '0',
#   'product_name': 'Science and Technology',
#   'author': 'agrahari ravi p',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '655',
#   'product_disc_price': '526',
#   'product_rating': '4.6',
#   'product_raters': '36',
#   'discount_offered_prcnt': '19',
#   'on_promotion': 'yes'},
#  {'sr_no': '1',
#   'product_name': 'Think and Grow Rich',
#   'author': 'hill napoleon',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '102',
#   'product_rating': '4.5',
#   'product_raters': '52575',
#   'discount_offered_prcnt': '54',
#   'on_promotion': 'yes'},
#  {'sr_no': '2',
#   'product_name': 'Quantitative Aptitude for Competitive Examinations with...',
#   'author': 'aggarwal r. s.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '749',
#   'product_disc_price': '454',
#   'product_rating': '4.4',
#   'product_raters': '56087',
#   'discount_offered_prcnt': '39',
#   'on_promotion': 'No'},
#  {'sr_no': '3',
#   'product_name': "Life's Amazing Secrets how to find balance",
#   'author': 'das gaur gopal',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '161',
#   'product_rating': '4.6',
#   'product_raters': '39847',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '4',
#   'product_name': 'The Psychology of Money',
#   'author': 'housel morgan',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '399',
#   'product_disc_price': '247',
#   'product_rating': '4.6',
#   'product_raters': '3554',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'No'},
#  {'sr_no': '5',
#   'product_name': 'Because Life is a Gift - Stories of Hope, Courage and P...',
#   'author': 'disha',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.3',
#   'product_raters': '7786',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'No'},
#  {'sr_no': '6',
#   'product_name': 'Sawal hi jawab hai',
#   'author': 'allan pease',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '150',
#   'product_disc_price': '90',
#   'product_rating': '4.4',
#   'product_raters': '7386',
#   'discount_offered_prcnt': '40',
#   'on_promotion': 'No'},
#  {'sr_no': '7',
#   'product_name': 'Indian Polity - for Civil Services and Other State Exam...',
#   'author': 'laxmikanth m.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '940',
#   'product_disc_price': '639',
#   'product_rating': '4.6',
#   'product_raters': '36682',
#   'discount_offered_prcnt': '32',
#   'on_promotion': 'No'},
#  {'sr_no': '8',
#   'product_name': 'Rahasya / The Secret',
#   'author': 'byrne rhonda',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '399',
#   'product_disc_price': '246',
#   'product_rating': '4.5',
#   'product_raters': '11123',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'No'},
#  {'sr_no': '9',
#   'product_name': 'Nta UGC Net/ Set/ Jrf Paper 1 Teaching and Research Apt...',
#   'author': 'madaan k.v.s.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '449',
#   'product_disc_price': '256',
#   'product_rating': '4.5',
#   'product_raters': '449',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'No'},
#  {'sr_no': '10',
#   'product_name': '15 Practice Sets Ssc Constable Gd 2021',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '140',
#   'product_disc_price': '112',
#   'product_rating': '4.3',
#   'product_raters': '1205',
#   'discount_offered_prcnt': '20',
#   'on_promotion': 'No'},
#  {'sr_no': '11',
#   'product_name': 'Rich Dad Poor Dad',
#   'author': 'kiyosaki robert t.',
#   'language': 'Telugu',
#   'type': 'Paperback',
#   'product_real_price': '399',
#   'product_disc_price': '247',
#   'product_rating': '4.4',
#   'product_raters': '7583',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'No'},
#  {'sr_no': '12',
#   'product_name': 'Objective Computer Awareness',
#   'author': 'arihant experts',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '140',
#   'product_disc_price': '123',
#   'product_rating': '4.4',
#   'product_raters': '7335',
#   'discount_offered_prcnt': '12',
#   'on_promotion': 'No'},
#  {'sr_no': '13',
#   'product_name': 'Why I am an Atheist and Other Works',
#   'author': 'singh bhagat',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.6',
#   'product_raters': '5670',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '14',
#   'product_name': 'Oxford Student Atlas for India',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '315',
#   'product_disc_price': '230',
#   'product_rating': '4.5',
#   'product_raters': '34485',
#   'discount_offered_prcnt': '26',
#   'on_promotion': 'No'},
#  {'sr_no': '15',
#   'product_name': 'General Knowledge 2022',
#   'author': 'pandey manohar',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '195',
#   'product_disc_price': '148',
#   'product_rating': '4.4',
#   'product_raters': '1915',
#   'discount_offered_prcnt': '24',
#   'on_promotion': 'No'},
#  {'sr_no': '16',
#   'product_name': 'One Arranged Murder',
#   'author': 'bhagat chetan',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '152',
#   'product_rating': '4.6',
#   'product_raters': '19255',
#   'discount_offered_prcnt': '32',
#   'on_promotion': 'No'},
#  {'sr_no': '17',
#   'product_name': 'Guide to Ssc Constable & Rifleman (Gd) Exam',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '420',
#   'product_disc_price': '241',
#   'product_rating': '4.3',
#   'product_raters': '606',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'yes'},
#  {'sr_no': '18',
#   'product_name': 'Attitude is Everything: Change Your Attitude ... Change...',
#   'author': 'keller jeff',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '160',
#   'product_rating': '4.5',
#   'product_raters': '43571',
#   'discount_offered_prcnt': '19',
#   'on_promotion': 'No'},
#  {'sr_no': '19',
#   'product_name': '26 Years Upsc IAS/ Ips Prelims Topic-Wise Solved Papers...',
#   'author': 'patel mrunal',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '575',
#   'product_disc_price': '321',
#   'product_rating': '4.5',
#   'product_raters': '10702',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'No'},
#  {'sr_no': '20',
#   'product_name': 'How to Crack Test of Reasoning',
#   'author': 'jaikishan premkishan',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '235',
#   'product_disc_price': '166',
#   'product_rating': '4.4',
#   'product_raters': '20401',
#   'discount_offered_prcnt': '29',
#   'on_promotion': 'No'},
#  {'sr_no': '21',
#   'product_name': 'FITNESS HABITS: Breaking the Barriers to Fitness',
#   'author': 'ojha amaresh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '158',
#   'product_rating': '4.2',
#   'product_raters': '47',
#   'discount_offered_prcnt': '36',
#   'on_promotion': 'yes'},
#  {'sr_no': '22',
#   'product_name': 'Rapid General Knowledge 2021 for Competitive Exams',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '35',
#   'product_disc_price': '30',
#   'product_rating': '4.4',
#   'product_raters': '5272',
#   'discount_offered_prcnt': '14',
#   'on_promotion': 'No'},
#  {'sr_no': '23',
#   'product_name': 'Ssc Multi Tasking Non-Technical Guide 2021',
#   'author': 'unknown',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '265',
#   'product_disc_price': '183',
#   'product_rating': '4.2',
#   'product_raters': '1890',
#   'discount_offered_prcnt': '30',
#   'on_promotion': 'No'},
#  {'sr_no': '24',
#   'product_name': 'Rich Dad Poor Dad',
#   'author': 'kiyosaki robert t.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '499',
#   'product_disc_price': '302',
#   'product_rating': '4.5',
#   'product_raters': '32796',
#   'discount_offered_prcnt': '39',
#   'on_promotion': 'No'},
#  {'sr_no': '25',
#   'product_name': 'Magical Mythology',
#   'author': 'gupta stuti',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '295',
#   'product_disc_price': '174',
#   'product_rating': '4.7',
#   'product_raters': '23',
#   'discount_offered_prcnt': '41',
#   'on_promotion': 'yes'},
#  {'sr_no': '26',
#   'product_name': '33 Years NEET-AIPMT Chapterwise Solutions -Physics, Che...',
#   'author': 'mtg editorial board',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '950',
#   'product_disc_price': '530',
#   'product_rating': '4.5',
#   'product_raters': '5452',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'No'},
#  {'sr_no': '27',
#   'product_name': 'Objective Ncert at Your Fingertips for Neet-Aiims - Bio...',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '900',
#   'product_disc_price': '540',
#   'product_rating': '4.6',
#   'product_raters': '25997',
#   'discount_offered_prcnt': '40',
#   'on_promotion': 'No'},
#  {'sr_no': '28',
#   'product_name': 'ALCHEMIST',
#   'author': 'paulo coelho',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '350',
#   'product_disc_price': '210',
#   'product_rating': '4.6',
#   'product_raters': '50670',
#   'discount_offered_prcnt': '40',
#   'on_promotion': 'No'},
#  {'sr_no': '29',
#   'product_name': 'You are the Best Wife',
#   'author': 'pandey ajay k.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '127',
#   'product_rating': '4.5',
#   'product_raters': '12189',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'yes'},
#  {'sr_no': '30',
#   'product_name': 'Indian Art and Culture for Civil Services and Other Com...',
#   'author': 'singhania nitin',
#   'language': 'English',
#   'type': 'Hardcover',
#   'product_real_price': '825',
#   'product_disc_price': '555',
#   'product_rating': '4.6',
#   'product_raters': '13136',
#   'discount_offered_prcnt': '32',
#   'on_promotion': 'No'},
#  {'sr_no': '31',
#   'product_name': 'Ignited Minds - Unleashing the Power within India',
#   'author': 'kalam a p j abdul',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '143',
#   'product_rating': '4.6',
#   'product_raters': '8609',
#   'discount_offered_prcnt': '28',
#   'on_promotion': 'No'},
#  {'sr_no': '32',
#   'product_name': "Lucent's - General Knowledge 2020 Edition",
#   'author': "lucent's expert team",
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '179',
#   'product_rating': '4.5',
#   'product_raters': '36405',
#   'discount_offered_prcnt': '20',
#   'on_promotion': 'No'},
#  {'sr_no': '33',
#   'product_name': 'Authentic Shortcuts, Tips & Tricks in Physics for Jee M...',
#   'author': 'gupta harsh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '155',
#   'product_rating': '4.3',
#   'product_raters': '1517',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'yes'},
#  {'sr_no': '34',
#   'product_name': 'Power of Your Subconscious Mind & Think and Grow Rich -...',
#   'author': 'joseph murphy napoleon hill',
#   'language': 'other',
#   'type': 'Boxset',
#   'product_real_price': '399',
#   'product_disc_price': '135',
#   'product_rating': '4.7',
#   'product_raters': '121',
#   'discount_offered_prcnt': '66',
#   'on_promotion': 'No'},
#  {'sr_no': '35',
#   'product_name': 'Baniye Network Marketing Millionaire - Network marketin...',
#   'author': 'unknown',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '166',
#   'product_rating': '4.5',
#   'product_raters': '5992',
#   'discount_offered_prcnt': '26',
#   'on_promotion': 'No'},
#  {'sr_no': '36',
#   'product_name': 'Why Not Me? A Feeling of Millions (English)',
#   'author': 'agrawal anubhav',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '120',
#   'product_rating': '4.6',
#   'product_raters': '5033',
#   'discount_offered_prcnt': '39',
#   'on_promotion': 'No'},
#  {'sr_no': '37',
#   'product_name': 'Life is What You Make it',
#   'author': 'shenoy preeti',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '150',
#   'product_disc_price': '112',
#   'product_rating': '4.3',
#   'product_raters': '21819',
#   'discount_offered_prcnt': '25',
#   'on_promotion': 'yes'},
#  {'sr_no': '38',
#   'product_name': 'CBSE All In One English Language & Literature Class 10 ...',
#   'author': 'agarwal srishti',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '475',
#   'product_disc_price': '330',
#   'product_rating': '4.6',
#   'product_raters': '1279',
#   'discount_offered_prcnt': '30',
#   'on_promotion': 'No'},
#  {'sr_no': '39',
#   'product_name': 'Fast Track Objective Arithmetic',
#   'author': 'verma rajesh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '465',
#   'product_disc_price': '298',
#   'product_rating': '4.5',
#   'product_raters': '28592',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '40',
#   'product_name': 'Time Management',
#   'author': 'dixit sudhir',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '125',
#   'product_disc_price': '79',
#   'product_rating': '4.4',
#   'product_raters': '16418',
#   'discount_offered_prcnt': '36',
#   'on_promotion': 'No'},
#  {'sr_no': '41',
#   'product_name': 'Because Life is a Gift - Stories of Hope, Courage and P...',
#   'author': 'disha',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.3',
#   'product_raters': '7786',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '42',
#   'product_name': 'The Secret',
#   'author': 'byrne rhonda',
#   'language': 'English',
#   'type': 'Hardcover',
#   'product_real_price': '799',
#   'product_disc_price': '477',
#   'product_rating': '4.5',
#   'product_raters': '21105',
#   'discount_offered_prcnt': '40',
#   'on_promotion': 'No'},
#  {'sr_no': '43',
#   'product_name': '13 Years Solved Papers NEET 2021',
#   'author': 'arihant experts',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '480',
#   'product_disc_price': '294',
#   'product_rating': '4.4',
#   'product_raters': '1476',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'No'},
#  {'sr_no': '44',
#   'product_name': 'Lakshya',
#   'author': 'tracy brian',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '299',
#   'product_disc_price': '190',
#   'product_rating': '4.5',
#   'product_raters': '1842',
#   'discount_offered_prcnt': '36',
#   'on_promotion': 'No'},
#  {'sr_no': '45',
#   'product_name': 'Science and Technology',
#   'author': 'agrahari ravi p',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '655',
#   'product_disc_price': '526',
#   'product_rating': '4.6',
#   'product_raters': '36',
#   'discount_offered_prcnt': '19',
#   'on_promotion': 'yes'},
#  {'sr_no': '46',
#   'product_name': 'Pathfinder Nda/Na National Defence Academy & Naval Acad...',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '775',
#   'product_disc_price': '520',
#   'product_rating': '4.5',
#   'product_raters': '10345',
#   'discount_offered_prcnt': '32',
#   'on_promotion': 'No'},
#  {'sr_no': '47',
#   'product_name': 'Panakkara Thanthai Yezhai Thanthai',
#   'author': 'kiyoski robert t.',
#   'language': 'Tamil',
#   'type': 'Paperback',
#   'product_real_price': '399',
#   'product_disc_price': '223',
#   'product_rating': '4.5',
#   'product_raters': '2613',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'No'},
#  {'sr_no': '48',
#   'product_name': 'Great Stories for Children',
#   'author': 'bond ruskin',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '195',
#   'product_disc_price': '127',
#   'product_rating': '4.5',
#   'product_raters': '11090',
#   'discount_offered_prcnt': '34',
#   'on_promotion': 'No'},
#  {'sr_no': '49',
#   'product_name': 'Think and Grow Rich',
#   'author': 'hill napoleon',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '102',
#   'product_rating': '4.5',
#   'product_raters': '52575',
#   'discount_offered_prcnt': '54',
#   'on_promotion': 'yes'},
#  {'sr_no': '50',
#   'product_name': 'CBSE All In One Chemistry Class 11 for 2022 Exam (Updat...',
#   'author': 'gupta preeti',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '540',
#   'product_disc_price': '385',
#   'product_rating': '4.5',
#   'product_raters': '366',
#   'discount_offered_prcnt': '28',
#   'on_promotion': 'No'},
#  {'sr_no': '51',
#   'product_name': 'Miss & Chief My First Book Of Patterns Pencil Control',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '89',
#   'product_rating': '4.5',
#   'product_raters': '2138',
#   'discount_offered_prcnt': '55',
#   'on_promotion': 'No'},
#  {'sr_no': '52',
#   'product_name': 'CBSE All In One Social Science Class 9 for 2022 Exam (U...',
#   'author': 'pattrea madhumitta',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '465',
#   'product_disc_price': '319',
#   'product_rating': '4.5',
#   'product_raters': '491',
#   'discount_offered_prcnt': '31',
#   'on_promotion': 'No'},
#  {'sr_no': '53',
#   'product_name': 'Wise & Otherwise',
#   'author': 'sudha murthy',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '178',
#   'product_rating': '4.5',
#   'product_raters': '6086',
#   'discount_offered_prcnt': '28',
#   'on_promotion': 'No'},
#  {'sr_no': '54',
#   'product_name': 'Objective General English',
#   'author': 'bakshi s.p.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '285',
#   'product_disc_price': '195',
#   'product_rating': '4.4',
#   'product_raters': '51273',
#   'discount_offered_prcnt': '31',
#   'on_promotion': 'No'},
#  {'sr_no': '55',
#   'product_name': 'Manorama Year Book 2021 Covid 19',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '300',
#   'product_disc_price': '269',
#   'product_rating': '4.6',
#   'product_raters': '4196',
#   'discount_offered_prcnt': '10',
#   'on_promotion': 'No'},
#  {'sr_no': '56',
#   'product_name': 'Ancient and Medieval India',
#   'author': 'dahiya poonam dalal',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '610',
#   'product_disc_price': '435',
#   'product_rating': '4.6',
#   'product_raters': '17083',
#   'discount_offered_prcnt': '28',
#   'on_promotion': 'No'},
#  {'sr_no': '57',
#   'product_name': 'Everything I Never Told You',
#   'author': 'pandey ajay k.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '110',
#   'product_rating': '4.5',
#   'product_raters': '3070',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'No'},
#  {'sr_no': '58',
#   'product_name': 'A Touch of Eternity',
#   'author': 'durjoy datta',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '152',
#   'product_rating': '4.5',
#   'product_raters': '2060',
#   'discount_offered_prcnt': '23',
#   'on_promotion': 'No'},
#  {'sr_no': '59',
#   'product_name': 'Why I am an Atheist and Other Works',
#   'author': 'singh bhagat',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.6',
#   'product_raters': '5670',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '60',
#   'product_name': 'CBSE All In One English Class 11 for 2022 Exam (Updated...',
#   'author': 'srishti agarwal nandini sharma',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '475',
#   'product_disc_price': '330',
#   'product_rating': '4.6',
#   'product_raters': '188',
#   'discount_offered_prcnt': '30',
#   'on_promotion': 'No'},
#  {'sr_no': '61',
#   'product_name': 'Secret ( Tamil )',
#   'author': 'rhonda byrne',
#   'language': 'Tamil',
#   'type': 'Paperback',
#   'product_real_price': '399',
#   'product_disc_price': '265',
#   'product_rating': '4.5',
#   'product_raters': '4885',
#   'discount_offered_prcnt': '33',
#   'on_promotion': 'No'},
#  {'sr_no': '62',
#   'product_name': 'The Secret',
#   'author': 'byrne rhonda',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '599',
#   'product_disc_price': '390',
#   'product_rating': '4.5',
#   'product_raters': '21105',
#   'discount_offered_prcnt': '34',
#   'on_promotion': 'No'},
#  {'sr_no': '63',
#   'product_name': 'Guide to Ssc Constable & Rifleman (Gd) Exam',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '420',
#   'product_disc_price': '241',
#   'product_rating': '4.3',
#   'product_raters': '606',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'yes'},
#  {'sr_no': '64',
#   'product_name': 'Bhartiya Kala Evam Sanskriti ( Indian Art and Culture )...',
#   'author': 'nitin singhania',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '690',
#   'product_disc_price': '470',
#   'product_rating': '4.6',
#   'product_raters': '5260',
#   'discount_offered_prcnt': '31',
#   'on_promotion': 'No'},
#  {'sr_no': '65',
#   'product_name': 'Atomic Habits',
#   'author': 'clear james',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '799',
#   'product_disc_price': '478',
#   'product_rating': '4.4',
#   'product_raters': '3997',
#   'discount_offered_prcnt': '40',
#   'on_promotion': 'No'},
#  {'sr_no': '66',
#   'product_name': 'Atomic Habits',
#   'author': 'clear james',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '299',
#   'product_disc_price': '192',
#   'product_rating': '4.5',
#   'product_raters': '709',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '67',
#   'product_name': 'Authentic Shortcuts, Tips & Tricks in Physics for Jee M...',
#   'author': 'gupta harsh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '155',
#   'product_rating': '4.3',
#   'product_raters': '1517',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'yes'},
#  {'sr_no': '68',
#   'product_name': 'Ssc Multi Tasking Non-Technical Guide 2021',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '270',
#   'product_disc_price': '169',
#   'product_rating': '4.2',
#   'product_raters': '2651',
#   'discount_offered_prcnt': '37',
#   'on_promotion': 'No'},
#  {'sr_no': '69',
#   'product_name': 'Samanya Gyan 2022',
#   'author': 'pandey manohar',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '145',
#   'product_disc_price': '103',
#   'product_rating': '4.3',
#   'product_raters': '284',
#   'discount_offered_prcnt': '28',
#   'on_promotion': 'No'},
#  {'sr_no': '70',
#   'product_name': '21vi SADI KA VYVASAYA - Nirankari enterprises (Rich dad...',
#   'author': 'robert t. kiyosaki',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '139',
#   'product_rating': '4.4',
#   'product_raters': '2331',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'No'},
#  {'sr_no': '71',
#   'product_name': '8 Years Upsc Civil Services IAS Mains English (Compulso...',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '140',
#   'product_disc_price': '112',
#   'product_rating': '4.4',
#   'product_raters': '353',
#   'discount_offered_prcnt': '20',
#   'on_promotion': 'yes'},
#  {'sr_no': '72',
#   'product_name': 'CBSE All In One Chemistry Class 12 for 2022 Exam (Updat...',
#   'author': 'gupta indu',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '540',
#   'product_disc_price': '383',
#   'product_rating': '4.4',
#   'product_raters': '445',
#   'discount_offered_prcnt': '29',
#   'on_promotion': 'No'},
#  {'sr_no': '73',
#   'product_name': 'Jeetna Hai to Jid Karo - Jeetna hain to jid karo Second...',
#   'author': 'hundiwalan s.',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '135',
#   'product_disc_price': '113',
#   'product_rating': '4.4',
#   'product_raters': '6896',
#   'discount_offered_prcnt': '16',
#   'on_promotion': 'No'},
#  {'sr_no': '74',
#   'product_name': 'Pathfinder Cds Combined Defence Services Entrance Exami...',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '775',
#   'product_disc_price': '575',
#   'product_rating': '4.5',
#   'product_raters': '4075',
#   'discount_offered_prcnt': '25',
#   'on_promotion': 'No'},
#  {'sr_no': '75',
#   'product_name': 'You are the Best Wife',
#   'author': 'pandey ajay k.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '127',
#   'product_rating': '4.5',
#   'product_raters': '12189',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'yes'},
#  {'sr_no': '76',
#   'product_name': '33 Years Chapterwise Solutions NEET Biology 2021',
#   'author': 'arihant experts',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '320',
#   'product_disc_price': '187',
#   'product_rating': '4.4',
#   'product_raters': '856',
#   'discount_offered_prcnt': '41',
#   'on_promotion': 'No'},
#  {'sr_no': '77',
#   'product_name': 'Secret',
#   'author': 'rhonda byrne',
#   'language': 'Marathi',
#   'type': 'Paperback',
#   'product_real_price': '399',
#   'product_disc_price': '262',
#   'product_rating': '4.4',
#   'product_raters': '2478',
#   'discount_offered_prcnt': '34',
#   'on_promotion': 'No'},
#  {'sr_no': '78',
#   'product_name': 'The Secret',
#   'author': 'byrne rhonda',
#   'language': 'Telugu',
#   'type': 'Paperback',
#   'product_real_price': '499',
#   'product_disc_price': '246',
#   'product_rating': '4.4',
#   'product_raters': '5167',
#   'discount_offered_prcnt': '50',
#   'on_promotion': 'No'},
#  {'sr_no': '79',
#   'product_name': 'Because Life is a Gift - Stories of Hope, Courage and P...',
#   'author': 'disha',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.3',
#   'product_raters': '7786',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '80',
#   'product_name': 'Indian Economy Key Concepts',
#   'author': 'karuppiah sankarganesh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '280',
#   'product_disc_price': '183',
#   'product_rating': '4.5',
#   'product_raters': '2829',
#   'discount_offered_prcnt': '34',
#   'on_promotion': 'No'},
#  {'sr_no': '81',
#   'product_name': 'The Theory Of Everything',
#   'author': 'stephen hawking',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '154',
#   'product_rating': '4.6',
#   'product_raters': '11033',
#   'discount_offered_prcnt': '22',
#   'on_promotion': 'No'},
#  {'sr_no': '82',
#   'product_name': 'One Indian Girl',
#   'author': 'bhagat chetan',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '195',
#   'product_disc_price': '105',
#   'product_rating': '4.3',
#   'product_raters': '47790',
#   'discount_offered_prcnt': '46',
#   'on_promotion': 'No'},
#  {'sr_no': '83',
#   'product_name': 'Science and Technology',
#   'author': 'agrahari ravi p',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '655',
#   'product_disc_price': '526',
#   'product_rating': '4.6',
#   'product_raters': '36',
#   'discount_offered_prcnt': '19',
#   'on_promotion': 'yes'},
#  {'sr_no': '84',
#   'product_name': "Toppers' Study Hacks",
#   'author': 'agarwal avinash',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '249',
#   'product_disc_price': '188',
#   'product_rating': '4.5',
#   'product_raters': '3224',
#   'discount_offered_prcnt': '24',
#   'on_promotion': 'No'},
#  {'sr_no': '85',
#   'product_name': 'CBSE All In One English Core Class 12 for 2022 Exam (Up...',
#   'author': 'srishti agarwal nandini sharma',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '465',
#   'product_disc_price': '337',
#   'product_rating': '4.5',
#   'product_raters': '388',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'No'},
#  {'sr_no': '86',
#   'product_name': 'IKIGAI',
#   'author': 'garcia hector',
#   'language': 'English',
#   'type': 'Hardcover',
#   'product_real_price': '550',
#   'product_disc_price': '317',
#   'product_rating': '4.6',
#   'product_raters': '19189',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'No'},
#  {'sr_no': '87',
#   'product_name': 'Think and Grow Rich',
#   'author': 'hill napoleon',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '102',
#   'product_rating': '4.5',
#   'product_raters': '52575',
#   'discount_offered_prcnt': '54',
#   'on_promotion': 'yes'},
#  {'sr_no': '88',
#   'product_name': 'CBSE All In One Social Science Class 10 for 2022 Exam (...',
#   'author': 'pattrea madhumitta',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '465',
#   'product_disc_price': '334',
#   'product_rating': '4.5',
#   'product_raters': '1684',
#   'discount_offered_prcnt': '28',
#   'on_promotion': 'No'},
#  {'sr_no': '89',
#   'product_name': 'Ikigai',
#   'author': 'garcia hector',
#   'language': 'Malayalam',
#   'type': 'Hardcover',
#   'product_real_price': '350',
#   'product_disc_price': '245',
#   'product_rating': '4.4',
#   'product_raters': '291',
#   'discount_offered_prcnt': '30',
#   'on_promotion': 'No'},
#  {'sr_no': '90',
#   'product_name': 'Mrityu: Jaanen Ek Mahayogi Se (Hindi Translation of Bes...',
#   'author': 'sadhguru',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '208',
#   'product_rating': '4.7',
#   'product_raters': '513',
#   'discount_offered_prcnt': '16',
#   'on_promotion': 'No'},
#  {'sr_no': '91',
#   'product_name': 'Concepts Of Physics Vol I & II With Solutions Of Both T...',
#   'author': 'paperbage h c verma',
#   'language': 'other',
#   'type': 'other',
#   'product_real_price': '1,370',
#   'product_disc_price': '1,009',
#   'product_rating': '4.6',
#   'product_raters': '2075',
#   'discount_offered_prcnt': '26',
#   'on_promotion': 'No'},
#  {'sr_no': '92',
#   'product_name': 'Pathfinder Nda/Na National Defence Academy & Naval Acad...',
#   'author': 'unknown',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '765',
#   'product_disc_price': '497',
#   'product_rating': '4.4',
#   'product_raters': '1296',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '93',
#   'product_name': 'The Girl Who Knew Too Much - What if the Loved One You ...',
#   'author': 'khanna vikrant',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '129',
#   'product_rating': '4.4',
#   'product_raters': '10425',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '94',
#   'product_name': 'CBSE All in One Mathematics Class 10 for 2022 Exam (Upd...',
#   'author': 'prem kumar jitendra gupta brijesh dwivedi',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '525',
#   'product_disc_price': '353',
#   'product_rating': '4.5',
#   'product_raters': '290',
#   'discount_offered_prcnt': '32',
#   'on_promotion': 'No'},
#  {'sr_no': '95',
#   'product_name': 'A New Approach to Reasoning - Verbal, Non - Verbal & An...',
#   'author': 'sijwalii b.s.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '625',
#   'product_disc_price': '490',
#   'product_rating': '4.5',
#   'product_raters': '16920',
#   'discount_offered_prcnt': '21',
#   'on_promotion': 'No'},
#  {'sr_no': '96',
#   'product_name': '8 Varsh UPSC Civil Sewa IAS Mains Hindi (Anivarya) Year...',
#   'author': 'disha experts',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '140',
#   'product_disc_price': '79',
#   'product_rating': '4.6',
#   'product_raters': '159',
#   'discount_offered_prcnt': '43',
#   'on_promotion': 'No'},
#  {'sr_no': '97',
#   'product_name': 'Why I am an Atheist and Other Works',
#   'author': 'singh bhagat',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.6',
#   'product_raters': '5670',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '98',
#   'product_name': 'Ekkisvin Shatabdi Mein Antrashtriya Sambandh',
#   'author': 'unknown',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '220',
#   'product_disc_price': '159',
#   'product_rating': '4.4',
#   'product_raters': '553',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'No'},
#  {'sr_no': '99',
#   'product_name': '33 Years Chapterwise Solutions NEET Physics 2021',
#   'author': 'arihant experts',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '320',
#   'product_disc_price': '187',
#   'product_rating': '4.5',
#   'product_raters': '729',
#   'discount_offered_prcnt': '41',
#   'on_promotion': 'No'},
#  {'sr_no': '100',
#   'product_name': 'Eat that Frog! - 21 Great Ways to Stop Procastinating a...',
#   'author': 'brian tracy',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '182',
#   'product_rating': '4.6',
#   'product_raters': '5082',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'No'},
#  {'sr_no': '101',
#   'product_name': 'Guide to Ssc Constable & Rifleman (Gd) Exam',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '420',
#   'product_disc_price': '241',
#   'product_rating': '4.3',
#   'product_raters': '606',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'yes'},
#  {'sr_no': '102',
#   'product_name': 'Think and Grow Rich',
#   'author': 'hill napoleon',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '85',
#   'product_rating': '4.5',
#   'product_raters': '52575',
#   'discount_offered_prcnt': '57',
#   'on_promotion': 'No'},
#  {'sr_no': '103',
#   'product_name': 'Miss & Chief Colouring Books For Kids(Pack of 12 Books)',
#   'author': 'wonder house books',
#   'language': 'English',
#   'type': 'Box',
#   'product_real_price': '799',
#   'product_disc_price': '284',
#   'product_rating': '4.7',
#   'product_raters': '50',
#   'discount_offered_prcnt': '64',
#   'on_promotion': 'No'},
#  {'sr_no': '104',
#   'product_name': 'HOW TO TALK TO ANYONE',
#   'author': 'leil lowndes',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '299',
#   'product_disc_price': '194',
#   'product_rating': '4.4',
#   'product_raters': '5265',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '105',
#   'product_name': 'FITNESS HABITS: Breaking the Barriers to Fitness',
#   'author': 'ojha amaresh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '158',
#   'product_rating': '4.2',
#   'product_raters': '47',
#   'discount_offered_prcnt': '36',
#   'on_promotion': 'yes'},
#  {'sr_no': '106',
#   'product_name': 'Objective NCERT Gear Up Biology for NEET-AIIMS - Biolog...',
#   'author': 'ajay mohan',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '850',
#   'product_disc_price': '558',
#   'product_rating': '4.5',
#   'product_raters': '254',
#   'discount_offered_prcnt': '34',
#   'on_promotion': 'No'},
#  {'sr_no': '107',
#   'product_name': 'Inner Engineering (Hindi)',
#   'author': 'sadhguru',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '199',
#   'product_disc_price': '133',
#   'product_rating': '4.6',
#   'product_raters': '6565',
#   'discount_offered_prcnt': '33',
#   'on_promotion': 'No'},
#  {'sr_no': '108',
#   'product_name': 'The 5 AM Club',
#   'author': 'sharma robin',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '350',
#   'product_disc_price': '218',
#   'product_rating': '4.5',
#   'product_raters': '14801',
#   'discount_offered_prcnt': '37',
#   'on_promotion': 'No'},
#  {'sr_no': '109',
#   'product_name': 'Magical Mythology',
#   'author': 'gupta stuti',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '295',
#   'product_disc_price': '174',
#   'product_rating': '4.7',
#   'product_raters': '23',
#   'discount_offered_prcnt': '41',
#   'on_promotion': 'yes'},
#  {'sr_no': '110',
#   'product_name': 'Something I Never Told You',
#   'author': 'bhinder shravya',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '172',
#   'product_rating': '4.5',
#   'product_raters': '10172',
#   'discount_offered_prcnt': '31',
#   'on_promotion': 'No'},
#  {'sr_no': '111',
#   'product_name': 'Rich Dad Poor Dad',
#   'author': 'kiyosaki robert t.',
#   'language': 'Marathi',
#   'type': 'Paperback',
#   'product_real_price': '299',
#   'product_disc_price': '178',
#   'product_rating': '4.5',
#   'product_raters': '4307',
#   'discount_offered_prcnt': '40',
#   'on_promotion': 'No'},
#  {'sr_no': '112',
#   'product_name': 'Objective NCERT At Your Fingertips(NEET) - Phy, Chem, B...',
#   'author': 'mtg',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '2,400',
#   'product_disc_price': '1,610',
#   'product_rating': '4.4',
#   'product_raters': '574',
#   'discount_offered_prcnt': '32',
#   'on_promotion': 'No'},
#  {'sr_no': '113',
#   'product_name': 'You are the Best Wife',
#   'author': 'pandey ajay k.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '127',
#   'product_rating': '4.5',
#   'product_raters': '12189',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'yes'},
#  {'sr_no': '114',
#   'product_name': 'The Winning Attitude',
#   'author': 'keller jeff',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '139',
#   'product_rating': '4.6',
#   'product_raters': '1799',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'No'},
#  {'sr_no': '115',
#   'product_name': '8 Years Upsc Civil Services IAS Mains English (Compulso...',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '140',
#   'product_disc_price': '112',
#   'product_rating': '4.4',
#   'product_raters': '353',
#   'discount_offered_prcnt': '20',
#   'on_promotion': 'No'},
#  {'sr_no': '116',
#   'product_name': 'BHU Banaras Hindu University B.sc Math Group Entrance E...',
#   'author': 'arihant experts',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '235',
#   'product_disc_price': '212',
#   'product_rating': '4.2',
#   'product_raters': '546',
#   'discount_offered_prcnt': '9',
#   'on_promotion': 'No'},
#  {'sr_no': '117',
#   'product_name': 'Because Life is a Gift - Stories of Hope, Courage and P...',
#   'author': 'disha',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.3',
#   'product_raters': '7786',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '118',
#   'product_name': 'Think and Grow Rich',
#   'author': 'hill napoleon',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '102',
#   'product_rating': '4.5',
#   'product_raters': '52575',
#   'discount_offered_prcnt': '54',
#   'on_promotion': 'No'},
#  {'sr_no': '119',
#   'product_name': 'Nta UGC Net Paper 1 Topic-Wise 52 Solved Papers (2020 t...',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '475',
#   'product_disc_price': '250',
#   'product_rating': '4.5',
#   'product_raters': '277',
#   'discount_offered_prcnt': '47',
#   'on_promotion': 'No'},
#  {'sr_no': '120',
#   'product_name': 'Nta UGC Net Management Paper 2',
#   'author': 'sharma bharti',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '635',
#   'product_disc_price': '400',
#   'product_rating': '4.5',
#   'product_raters': '94',
#   'discount_offered_prcnt': '37',
#   'on_promotion': 'No'},
#  {'sr_no': '121',
#   'product_name': 'Science and Technology',
#   'author': 'agrahari ravi p',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '655',
#   'product_disc_price': '526',
#   'product_rating': '4.6',
#   'product_raters': '36',
#   'discount_offered_prcnt': '19',
#   'on_promotion': 'yes'},
#  {'sr_no': '122',
#   'product_name': 'CBSE All In One Social Science Class 10 for 2022 Exam (...',
#   'author': 'pattrea madhumitta',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '465',
#   'product_disc_price': '334',
#   'product_rating': '4.5',
#   'product_raters': '1684',
#   'discount_offered_prcnt': '28',
#   'on_promotion': 'No'},
#  {'sr_no': '123',
#   'product_name': 'How to Prepare for Logical Reasoning for Cat',
#   'author': 'sharma arun',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '750',
#   'product_disc_price': '592',
#   'product_rating': '4.5',
#   'product_raters': '5942',
#   'discount_offered_prcnt': '21',
#   'on_promotion': 'No'},
#  {'sr_no': '124',
#   'product_name': 'How to Prepare for Logical Reasoning for Cat',
#   'author': 'sharma arun',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '750',
#   'product_disc_price': '530',
#   'product_rating': '4.5',
#   'product_raters': '5942',
#   'discount_offered_prcnt': '29',
#   'on_promotion': 'No'},
#  {'sr_no': '125',
#   'product_name': 'CBSE All In One Biology Class 12 for 2022 Exam (Updated...',
#   'author': 'batra hema',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '400',
#   'product_disc_price': '279',
#   'product_rating': '4.4',
#   'product_raters': '270',
#   'discount_offered_prcnt': '30',
#   'on_promotion': 'No'},
#  {'sr_no': '126',
#   'product_name': 'Sainik School Entrance Exam',
#   'author': 'arihant experts',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '265',
#   'product_disc_price': '164',
#   'product_rating': '4',
#   'product_raters': '33',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'No'},
#  {'sr_no': '127',
#   'product_name': 'Who Will Cry When You Die?',
#   'author': 'sharma robin s.',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '185',
#   'product_disc_price': '131',
#   'product_rating': '4.3',
#   'product_raters': '1080',
#   'discount_offered_prcnt': '29',
#   'on_promotion': 'No'},
#  {'sr_no': '128',
#   'product_name': 'Problems in General Physics',
#   'author': 'irodov i.e.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '130',
#   'product_disc_price': '84',
#   'product_rating': '4.5',
#   'product_raters': '10313',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '129',
#   'product_name': 'Upsc IAS Prelims Paper 1 & 2 General Studies 10 Year-Wi...',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '300',
#   'product_disc_price': '194',
#   'product_rating': '4.4',
#   'product_raters': '624',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '130',
#   'product_name': 'Objective Arithmetic (SSC and Railway Exam Special) - I...',
#   'author': 'aggarwal r. s.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '595',
#   'product_disc_price': '360',
#   'product_rating': '4.4',
#   'product_raters': '2636',
#   'discount_offered_prcnt': '39',
#   'on_promotion': 'No'},
#  {'sr_no': '131',
#   'product_name': 'Why I am an Atheist and Other Works',
#   'author': 'singh bhagat',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.6',
#   'product_raters': '5670',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '132',
#   'product_name': 'A Brief History Of Time',
#   'author': 'hawking stephen',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '399',
#   'product_disc_price': '220',
#   'product_rating': '4.5',
#   'product_raters': '14366',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'No'},
#  {'sr_no': '133',
#   'product_name': 'Peppa Pig: Little Library',
#   'author': 'board book peppa pig',
#   'language': 'English',
#   'type': 'other',
#   'product_real_price': '299',
#   'product_disc_price': '179',
#   'product_rating': '4.3',
#   'product_raters': '2588',
#   'discount_offered_prcnt': '40',
#   'on_promotion': 'No'},
#  {'sr_no': '134',
#   'product_name': "India's Most Fearless",
#   'author': 'aroor shiv',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '299',
#   'product_disc_price': '194',
#   'product_rating': '4.7',
#   'product_raters': '3847',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '135',
#   'product_name': 'Guide to Ssc Constable & Rifleman (Gd) Exam',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '420',
#   'product_disc_price': '241',
#   'product_rating': '4.3',
#   'product_raters': '606',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'yes'},
#  {'sr_no': '136',
#   'product_name': 'The NAMESAKE',
#   'author': 'jhumpa lahiri',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '350',
#   'product_disc_price': '239',
#   'product_rating': '4.6',
#   'product_raters': '3621',
#   'discount_offered_prcnt': '31',
#   'on_promotion': 'No'},
#  {'sr_no': '137',
#   'product_name': 'Aapke Avachetan Man Ki Shakti',
#   'author': 'marfi joshap',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '150',
#   'product_disc_price': '95',
#   'product_rating': '4.5',
#   'product_raters': '5354',
#   'discount_offered_prcnt': '36',
#   'on_promotion': 'No'},
#  {'sr_no': '138',
#   'product_name': 'The Murder of Roger Ackroyd',
#   'author': 'christie agatha',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '299',
#   'product_disc_price': '194',
#   'product_rating': '4.7',
#   'product_raters': '3660',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '139',
#   'product_name': 'You are the Best Wife',
#   'author': 'pandey ajay k.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '127',
#   'product_rating': '4.5',
#   'product_raters': '12189',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'yes'},
#  {'sr_no': '140',
#   'product_name': 'Encyclopedia of General Science for General Competition...',
#   'author': 'mukherji siddharth',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '335',
#   'product_disc_price': '201',
#   'product_rating': '4.4',
#   'product_raters': '993',
#   'discount_offered_prcnt': '40',
#   'on_promotion': 'No'},
#  {'sr_no': '141',
#   'product_name': 'Bhartiya Nausena Mr & NMR Steward, Cook Avum Topass Bha...',
#   'author': 'unknown',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '165',
#   'product_disc_price': '140',
#   'product_rating': '4.3',
#   'product_raters': '4007',
#   'discount_offered_prcnt': '15',
#   'on_promotion': 'No'},
#  {'sr_no': '142',
#   'product_name': 'Combo set of General knowledge and Fast track objective...',
#   'author': 'arihant experts',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '585',
#   'product_disc_price': '332',
#   'product_rating': '4.3',
#   'product_raters': '20',
#   'discount_offered_prcnt': '43',
#   'on_promotion': 'No'},
#  {'sr_no': '143',
#   'product_name': 'Authentic Shortcuts, Tips & Tricks in Physics for Jee M...',
#   'author': 'gupta harsh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '155',
#   'product_rating': '4.3',
#   'product_raters': '1517',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'yes'},
#  {'sr_no': '144',
#   'product_name': 'CBSE All In One English Language & Literature Class 9 f...',
#   'author': 'tanwar amit',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '465',
#   'product_disc_price': '344',
#   'product_rating': '4.6',
#   'product_raters': '314',
#   'discount_offered_prcnt': '26',
#   'on_promotion': 'No'},
#  {'sr_no': '145',
#   'product_name': 'CBSE All In One History Class 12 for 2022 Exam (Updated...',
#   'author': 'madhumita pattrea amibh ranjan',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '400',
#   'product_disc_price': '324',
# ...
#   'type': 'Paperback',
#   'product_real_price': '285',
#   'product_disc_price': '168',
#   'product_rating': '4',
#   'product_raters': '25',
#   'discount_offered_prcnt': '41',
#   'on_promotion': 'No'},
#  {'sr_no': '887',
#   'product_name': 'Jawahar Navodaya Vidyalaya Entrance Exam Book 2021 Clas...',
#   'author': 'arihant expters',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '325',
#   'product_disc_price': '244',
#   'product_rating': '4.3',
#   'product_raters': '319',
#   'discount_offered_prcnt': '24',
#   'on_promotion': 'No'},
#  {'sr_no': '888',
#   'product_name': 'Ssc Constable (Gd)',
#   'author': 'ram singh yadav',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '245',
#   'product_disc_price': '208',
#   'product_rating': '4.2',
#   'product_raters': '18',
#   'discount_offered_prcnt': '15',
#   'on_promotion': 'No'},
#  {'sr_no': '889',
#   'product_name': 'FITNESS HABITS: Breaking the Barriers to Fitness',
#   'author': 'ojha amaresh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '158',
#   'product_rating': '4.2',
#   'product_raters': '47',
#   'discount_offered_prcnt': '36',
#   'on_promotion': 'yes'},
#  {'sr_no': '890',
#   'product_name': 'Arihant General Knowledge 2022',
#   'author': 'manohar pandey',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '195',
#   'product_disc_price': '148',
#   'product_rating': '4.2',
#   'product_raters': '40',
#   'discount_offered_prcnt': '24',
#   'on_promotion': 'No'},
#  {'sr_no': '891',
#   'product_name': 'Oswaal CBSE MCQs Chapterwise For Term I & II, Class 10 ...',
#   'author': 'oswaal books',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '746',
#   'product_disc_price': '547',
#   'product_rating': '4.7',
#   'product_raters': '7',
#   'discount_offered_prcnt': '26',
#   'on_promotion': 'No'},
#  {'sr_no': '892',
#   'product_name': 'NCERT SAR UPSC COMBO, NCERT SAR Bhartiya Arthvyavastha ...',
#   'author': 'mahesh kumar barnwal',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '1,540',
#   'product_disc_price': '799',
#   'product_rating': '4.5',
#   'product_raters': '1944',
#   'discount_offered_prcnt': '48',
#   'on_promotion': 'No'},
#  {'sr_no': '893',
#   'product_name': 'Magical Mythology',
#   'author': 'gupta stuti',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '295',
#   'product_disc_price': '174',
#   'product_rating': '4.7',
#   'product_raters': '23',
#   'discount_offered_prcnt': '41',
#   'on_promotion': 'yes'},
#  {'sr_no': '894',
#   'product_name': 'S.K. Books Indian Army General Duty G.D. /N.E.R. (Engli...',
#   'author': 'ram singh yadav yajvender yadav',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '150',
#   'product_disc_price': '136',
#   'product_rating': '4.3',
#   'product_raters': '101',
#   'discount_offered_prcnt': '9',
#   'on_promotion': 'No'},
#  {'sr_no': '895',
#   'product_name': 'Know Your State Haryana',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '350',
#   'product_disc_price': '218',
#   'product_rating': '4.3',
#   'product_raters': '24',
#   'discount_offered_prcnt': '37',
#   'on_promotion': 'No'},
#  {'sr_no': '896',
#   'product_name': 'Oswaal CBSE MCQs Chapterwise For Term I & II, Class 10 ...',
#   'author': 'oswaal books',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '746',
#   'product_disc_price': '568',
#   'product_rating': '4.5',
#   'product_raters': '4',
#   'discount_offered_prcnt': '23',
#   'on_promotion': 'No'},
#  {'sr_no': '897',
#   'product_name': 'You are the Best Wife',
#   'author': 'pandey ajay k.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '127',
#   'product_rating': '4.5',
#   'product_raters': '12189',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'yes'},
#  {'sr_no': '898',
#   'product_name': 'Arihant Objective General English',
#   'author': 'sp bakshi',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '285',
#   'product_disc_price': '245',
#   'product_rating': '4.3',
#   'product_raters': '58',
#   'discount_offered_prcnt': '14',
#   'on_promotion': 'No'},
#  {'sr_no': '899',
#   'product_name': '15 Practice Sets Ignou B.Ed Entrance Exam 2020',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '195',
#   'product_disc_price': '113',
#   'product_rating': '4.2',
#   'product_raters': '212',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'No'},
#  {'sr_no': '900',
#   'product_name': 'Topicwise Question Bank in Biology for NEET (NTA) Based...',
#   'author': 'mhe',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '565',
#   'product_disc_price': '434',
#   'product_rating': '4.3',
#   'product_raters': '29',
#   'discount_offered_prcnt': '23',
#   'on_promotion': 'No'},
#  {'sr_no': '901',
#   'product_name': 'Because Life is a Gift - Stories of Hope, Courage and P...',
#   'author': 'disha',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.3',
#   'product_raters': '7786',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '902',
#   'product_name': 'Statistics Economics for Class 11',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '375',
#   'product_disc_price': '326',
#   'product_rating': '4.6',
#   'product_raters': '255',
#   'discount_offered_prcnt': '13',
#   'on_promotion': 'No'},
#  {'sr_no': '903',
#   'product_name': 'Drishti RAS Series Book 1 (Bharat Evam Vishwa Ka Itihaa...',
#   'author': 'drishti experts',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '495',
#   'product_disc_price': '424',
#   'product_rating': '4.3',
#   'product_raters': '118',
#   'discount_offered_prcnt': '14',
#   'on_promotion': 'No'},
#  {'sr_no': '904',
#   'product_name': 'Lucent Vastunishth Samanya Gyan',
#   'author': 'neeraj chandra chaudhry kiran kumari',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '360',
#   'product_disc_price': '285',
#   'product_rating': '4.4',
#   'product_raters': '124',
#   'discount_offered_prcnt': '20',
#   'on_promotion': 'No'},
#  {'sr_no': '905',
#   'product_name': 'Science and Technology',
#   'author': 'agrahari ravi p',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '655',
#   'product_disc_price': '526',
#   'product_rating': '4.6',
#   'product_raters': '36',
#   'discount_offered_prcnt': '19',
#   'on_promotion': 'yes'},
#  {'sr_no': '906',
#   'product_name': 'The Alchemist',
#   'author': 'coelho paulo',
#   'language': 'Malayalam',
#   'type': 'Paperback',
#   'product_real_price': '210',
#   'product_disc_price': '164',
#   'product_rating': '4.6',
#   'product_raters': '1488',
#   'discount_offered_prcnt': '21',
#   'on_promotion': 'No'},
#  {'sr_no': '907',
#   'product_name': 'Wren And Martin English Grammar And Composition (Regula...',
#   'author': 'p c wren h martin',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '730',
#   'product_disc_price': '457',
#   'product_rating': '4.5',
#   'product_raters': '896',
#   'discount_offered_prcnt': '37',
#   'on_promotion': 'No'},
#  {'sr_no': '908',
#   'product_name': '3 Varsh UPPSC Mains Varsh-vaar Solved Papers (2020 to 2...',
#   'author': 'disha experts',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '190',
#   'product_disc_price': '102',
#   'product_rating': '4.2',
#   'product_raters': '32',
#   'discount_offered_prcnt': '46',
#   'on_promotion': 'No'},
#  {'sr_no': '909',
#   'product_name': 'Think and Grow Rich',
#   'author': 'hill napoleon',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '225',
#   'product_disc_price': '102',
#   'product_rating': '4.5',
#   'product_raters': '52575',
#   'discount_offered_prcnt': '54',
#   'on_promotion': 'yes'},
#  {'sr_no': '910',
#   'product_name': 'Mathematics for Jee Main Third Edition',
#   'author': 'tewani g.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '995',
#   'product_disc_price': '630',
#   'product_rating': '4.4',
#   'product_raters': '2070',
#   'discount_offered_prcnt': '36',
#   'on_promotion': 'No'},
#  {'sr_no': '911',
#   'product_name': 'The Blue Umbrella',
#   'author': 'bond ruskin',
#   'language': 'English',
#   'type': 'Hardcover',
#   'product_real_price': '295',
#   'product_disc_price': '198',
#   'product_rating': '4.5',
#   'product_raters': '14481',
#   'discount_offered_prcnt': '32',
#   'on_promotion': 'No'},
#  {'sr_no': '912',
#   'product_name': 'Indian History And National Movement (Hindi)',
#   'author': 'drishti publications',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '360',
#   'product_disc_price': '293',
#   'product_rating': '4.5',
#   'product_raters': '321',
#   'discount_offered_prcnt': '18',
#   'on_promotion': 'No'},
#  {'sr_no': '913',
#   'product_name': 'AADITYA Vastunisth Samanya Hindi 2020 For All Competiti...',
#   'author': 'hard book  pawan kumar tiwari',
#   'language': 'Hindi',
#   'type': 'other',
#   'product_real_price': '225',
#   'product_disc_price': '180',
#   'product_rating': '4.4',
#   'product_raters': '915',
#   'discount_offered_prcnt': '20',
#   'on_promotion': 'No'},
#  {'sr_no': '914',
#   'product_name': 'COMBO: CSIR-JRF-NET: Life Sciences Fundamentals And Pra...',
#   'author': 'kumar pranav',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '970',
#   'product_disc_price': '560',
#   'product_rating': '4.5',
#   'product_raters': '5960',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'No'},
#  {'sr_no': '915',
#   'product_name': 'Shrimad Bhagwat Gita Mote Akshar Wali',
#   'author': 'gita press',
#   'language': 'Hindi',
#   'type': 'Hardcover',
#   'product_real_price': '250',
#   'product_disc_price': '134',
#   'product_rating': '4.6',
#   'product_raters': '825',
#   'discount_offered_prcnt': '46',
#   'on_promotion': 'No'},
#  {'sr_no': '916',
#   'product_name': 'Srimad Bhagavad Gita As It Is ( English )',
#   'author': 'his divine grace a.c. bhaktivedanta swami prabhupada',
#   'language': 'other',
#   'type': 'Hardcover',
#   'product_real_price': '415',
#   'product_disc_price': '221',
#   'product_rating': '4.8',
#   'product_raters': '672',
#   'discount_offered_prcnt': '46',
#   'on_promotion': 'No'},
#  {'sr_no': '917',
#   'product_name': '15 Practice Sets Ssc Constable Gd 2021',
#   'author': 'unknown',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '140',
#   'product_disc_price': '132',
#   'product_rating': '4.1',
#   'product_raters': '30',
#   'discount_offered_prcnt': '5',
#   'on_promotion': 'No'},
#  {'sr_no': '918',
#   'product_name': 'Why I am an Atheist and Other Works',
#   'author': 'singh bhagat',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '97',
#   'product_rating': '4.6',
#   'product_raters': '5670',
#   'discount_offered_prcnt': '44',
#   'on_promotion': 'yes'},
#  {'sr_no': '919',
#   'product_name': 'Set of 8 Panchatantra and Traditional Story Books colle...',
#   'author': 'inikao',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '280',
#   'product_disc_price': '240',
#   'product_rating': '4.2',
#   'product_raters': '603',
#   'discount_offered_prcnt': '14',
#   'on_promotion': 'No'},
#  {'sr_no': '920',
#   'product_name': 'Everything: Space',
#   'author': 'national geographic kids',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '450',
#   'product_disc_price': '275',
#   'product_rating': '4.5',
#   'product_raters': '34',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'No'},
#  {'sr_no': '921',
#   'product_name': 'Pharmacology for Medical Graduates, 4th Updated Edition',
#   'author': 'dr. shanbhag tara v.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '935',
#   'product_disc_price': '657',
#   'product_rating': '4.5',
#   'product_raters': '783',
#   'discount_offered_prcnt': '29',
#   'on_promotion': 'No'},
#  {'sr_no': '922',
#   'product_name': 'Guide to Ssc Constable & Rifleman (Gd) Exam',
#   'author': 'unknown',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '420',
#   'product_disc_price': '241',
#   'product_rating': '4.3',
#   'product_raters': '606',
#   'discount_offered_prcnt': '42',
#   'on_promotion': 'yes'},
#  {'sr_no': '923',
#   'product_name': 'Srimad Bhagavad Gita As It Is : Marathi\n(New Edition)',
#   'author': 'his divine grace a. c. bhaktivedanta swami prabhupada',
#   'language': 'Marathi',
#   'type': 'Hardcover',
#   'product_real_price': '500',
#   'product_disc_price': '224',
#   'product_rating': '4.7',
#   'product_raters': '2609',
#   'discount_offered_prcnt': '55',
#   'on_promotion': 'No'},
#  {'sr_no': '924',
#   'product_name': 'CBSE All In One Computer Science With Python Class 12 f...',
#   'author': 'neetu gaikwad',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '220',
#   'product_rating': '4.4',
#   'product_raters': '57',
#   'discount_offered_prcnt': '12',
#   'on_promotion': 'No'},
#  {'sr_no': '925',
#   'product_name': 'MPSC PSI-STI-ASO Aadhunik Maharashtracha Itihas Dr.S.S....',
#   'author': 'dr.s.s.gathal',
#   'language': 'Marathi',
#   'type': 'Paperback',
#   'product_real_price': '330',
#   'product_disc_price': '278',
#   'product_rating': '4.4',
#   'product_raters': '184',
#   'discount_offered_prcnt': '15',
#   'on_promotion': 'No'},
#  {'sr_no': '926',
#   'product_name': 'You are the Best Wife',
#   'author': 'pandey ajay k.',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '175',
#   'product_disc_price': '127',
#   'product_rating': '4.5',
#   'product_raters': '12189',
#   'discount_offered_prcnt': '27',
#   'on_promotion': 'yes'},
#  {'sr_no': '927',
#   'product_name': 'Objective NCERT At Your FINGERTIPS For NEET-AIIMS - Bio...',
#   'author': 'provide in headline',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '900',
#   'product_disc_price': '584',
#   'product_rating': '4.6',
#   'product_raters': '358',
#   'discount_offered_prcnt': '35',
#   'on_promotion': 'No'},
#  {'sr_no': '928',
#   'product_name': 'Master the Ncert for Neet Rasayan Vigyan Part - 1 2020',
#   'author': 'unknown',
#   'language': 'Hindi',
#   'type': 'Paperback',
#   'product_real_price': '260',
#   'product_disc_price': '213',
#   'product_rating': '4.3',
#   'product_raters': '274',
#   'discount_offered_prcnt': '18',
#   'on_promotion': 'No'},
#  {'sr_no': '929',
#   'product_name': 'Solomons, Fryhle, Snyder Organic Chemistry for JEE (Mai...',
#   'author': 'm s chouhan',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '939',
#   'product_disc_price': '715',
#   'product_rating': '4.5',
#   'product_raters': '129',
#   'discount_offered_prcnt': '23',
#   'on_promotion': 'No'},
#  {'sr_no': '930',
#   'product_name': 'Authentic Shortcuts, Tips & Tricks in Physics for Jee M...',
#   'author': 'gupta harsh',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '250',
#   'product_disc_price': '155',
#   'product_rating': '4.3',
#   'product_raters': '1517',
#   'discount_offered_prcnt': '38',
#   'on_promotion': 'yes'},
#  {'sr_no': '931',
#   'product_name': 'Mujhe Bananaa Hai Upsc Topper',
#   'author': 'jain nishant',
#   'language': 'Hindi',
#   'type': 'Book',
#   'product_real_price': '250',
#   'product_disc_price': '205',
#   'product_rating': '4.5',
#   'product_raters': '5277',
#   'discount_offered_prcnt': '18',
#   'on_promotion': 'No'},
#  {'sr_no': '932',
#   'product_name': 'JEE Main Chapterwise Solved Papers 2020-2010 Bhotiki 20...',
#   'author': 'arihant experts',
#   'language': 'other',
#   'type': 'Paperback',
#   'product_real_price': '285',
#   'product_disc_price': '188',
#   'product_rating': '4.5',
#   'product_raters': '76',
#   'discount_offered_prcnt': '34',
#   'on_promotion': 'No'},
#  {'sr_no': '933',
#   'product_name': 'Life is What You Make it',
#   'author': 'shenoy preeti',
#   'language': 'English',
#   'type': 'Paperback',
#   'product_real_price': '150',
#   'product_disc_price': '112',
#   'product_rating': '4.3',
#   'product_raters': '21819',
#   'discount_offered_prcnt': '25',
#   'on_promotion': 'yes'}]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\thaha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Pre-process data

# %% [markdown]
# Here we iterate through the patterns and tokenize the sentence using nltk.word_tokenize() function and append each word in the words list. We also create a list of classes for our tags.

# %%
# Initialize lists for tokenization and intent classification
words = []
documents = []
classes = []

# Tokenize the query templates and create training data
for intent in intents["intents"]:
    for pattern in intent["query_templates"]:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w, intent["tag"]))
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# %% [markdown]
# lemmatize each word and remove duplicate words from the list

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 14 documents
# 4 classes ['author_inquiry', 'goodbye', 'greeting', 'product_inquiry']
# 28 unique lemmatized words ['[', ']', 'about', 'author', 'been', 'book', 'by', 'bye', 'can', 'goodbye', 'have', 'hello', 'hey', 'hi', 'i', 'later', 'learn', 'me', 'more', 'product_name', 'published', 'see', 'tell', 'the', 'to', 'want', 'what', 'you']

# %%
# Create a list of query templates from the JSON data
query_templates = []
for intent in intents['intents']:
    if 'query_templates' in intent:
        query_templates.extend(intent['query_templates'])

#csv [dataframe]        
# # Extract product names from the DataFrame and convert to a list
# product_names = product_data['product_name'].tolist()

#json format
# Extract product names into a list
product_names = [item['product_name'] for item in product_data]
author = [item['author'] for item in product_data]

# Combine query templates and product names
combined_data = query_templates + product_names

# Lemmatize and lowercase each word, remove duplicates
lemmatizer = WordNetLemmatizer()
ignore_words = ["?"]
words = [lemmatizer.lemmatize(w.lower()) for w in combined_data if w not in ignore_words]
words = sorted(list(set(words)))  # Fixed the typo here

# Sort classes (intents)
classes = sorted([intent['tag'] for intent in intents['intents']])

# Save words and classes to pickle files
with open('words.pkl', 'wb') as words_file:
    pickle.dump(words, words_file)
with open('classes.pkl', 'wb') as classes_file:
    pickle.dump(classes, classes_file)

# Print information about the data
print(len(combined_data), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)
# Out:
# 948 documents
# 4 classes ['author_inquiry', 'goodbye', 'greeting', 'product_inquiry']
# 686 unique lemmatized words ['10 neet ug mock test paper as per nta new paper pattern...', '10 practice sets nda/na defence academy & naval academy...', '10000+ objective general studies mcqs with explanatory ...', '101 best indian fables for children', '101 panchtantra stories (paperback)', '13 years solved papers neet 2021', '13 years solved papers neet bhautiki,rasayan vigyan & j...', '14 years neet solved papers powered with tips, tricks &...', '14000+ chapterwise questions objective general studies ...', '15 practice sets ignou b.ed entrance exam 2020', '15 practice sets ssc constable gd 2021', '15 practice sets up b.ed jee kala varg for 2021 exam', '151 essays for ias/ pcs & other competitive exams', '151 nibandh for ias/pcs & other competitive exams', '16 years solved papers for amu engineering entrance exa...', '18 years chapterwise solutions mathematics jee main 202...', '19 afcat year-wise (2021 - 11) solved papers', '2 states - the story of my marriage', '20 practice jawahar navodaya vidyalaya 2021 for class 6', '2019: how modi won india', '21vi sadi ka vyvasaya - nirankari enterprises (rich dad...', '26 years chapterwise solved questions upsc ias pre gene...', '26 years upsc ias/ ips prelims topic-wise solved papers...', '3 varsh uppsc mains varsh-vaar solved papers (2020 to 2...', '30 days to a more powerful vocabulary', '30 pratice sets indian navy senior secondary recruitmen...', '33 years chapterwise solutions neet biology 2021', '33 years chapterwise solutions neet physics 2021', '33 years neet chapterwise & topicwise solved papers che...', '33 years neet chapterwise & topicwise solved papers phy...', '33 years neet-aipmt chapterwise solutions - biology 202...', '33 years neet-aipmt chapterwise solutions -physics, che...', '33 yearsã¢â€â™ chapter-wise and topic-wise solved papers (...', '36 ugc net paper 1 year-wise solved paper (2020 to 2004...', '40 days crash course for neet biology', '40 days crash course for neet chemistry', '40 days jee main ganit 2021', '40 days neet jeev vigyan 2021', '42 years addhyaywar solved papers (2020-1979) iit jee r...', '42 years chapterwise topicwise solved papers (2020-1979...', '43 jee main physics online (2019-2012) & offline (2018-...', '43 years jee advanced (1978 - 2020) + jee main chapter ...', '43 years jee advanced (1978 - 2020) + jee main chapterw...', '5 practice sets for nda/ na exam', '50 practice sets bhartiye thal sena clerk skt and gd bh...', '7 divine laws to awaken your best self', '7 year-wise mh-cet (mba / mms) solved papers (2014 - 20...', '7300+ ssc mathematics by rakesh yadav / 1999 to till da...', '8 varsh upsc civil sewa ias mains hindi (anivarya) year...', '8 years upsc civil services ias mains english (compulso...', '8 years upsc civil services ias mains general studies p...', '[author]', '[product_name]', 'a brief history of modern india', 'a brief history of time', 'a court of silver flames', 'a handbook for letter writing', 'a new approach to reasoning - verbal, non - verbal & an...', 'a poem a day', 'a problem book in mathematical analysis', 'a tb of physical chemistry vol 1', 'a touch of eternity', 'aaditya vastunisth samanya hindi 2020 for all competiti...', 'aapke avachetan man ki shakti', 'aapki skill aapki udaan : up your game', 'ab de villiers - the autobiography', 'achieve more, succeed faster', 'adiyogi', 'afcat (flying technical & ground duty branch) 2021', 'afcat 15 practice sets and solved papers 2021', 'after - a wattpad novel', 'after we collided', 'agnichirakukal', 'al-quran al-kareem(large) ref no 81 with tajweed rules ...', 'alchemist', 'all in one chemistry icse class 9 2021-22', 'all in one chemistry isc class 11 2021-22', 'all in one physics icse class 9 2021-22', 'all-time favourites for children', 'ancient and medieval india', 'and then there were none', 'andhra pradesh eamcet engineering 20 years solved paper...', 'annihilation of caste', 'arihant cbse chapterwise solved papers physics, chemist...', 'arihant cbse new patter ...

# %% [markdown]
# ## Create training and testing data

# %%
# Create our training data
training = []
# Create an empty array for our output
output_empty = [0] * len(classes)

# Training set, bag of words for each sentence
for doc in documents:
    # Initialize our bag of words
    bag = []
    # List of tokenized words for the pattern
    pattern_words = doc[0]
    # Lemmatize each word - create base word, in an attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # Create our bag of words array with 1, if word match found in the current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # Output is '0' for each tag and '1' for the current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

# Shuffle our features
random.shuffle(training)

# Separate the features (X - patterns) and labels (Y - intents)
train_x = [item[0] for item in training]
train_y = [item[1] for item in training]

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ## Create Model

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3844 - accuracy: 0.2857
# Epoch 2/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3792 - accuracy: 0.3571
# Epoch 3/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3768 - accuracy: 0.3571
# Epoch 4/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3598 - accuracy: 0.4286
# Epoch 5/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3581 - accuracy: 0.5000
# Epoch 6/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3461 - accuracy: 0.4286
# Epoch 7/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3395 - accuracy: 0.4286
# Epoch 8/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3414 - accuracy: 0.3571
# Epoch 9/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3579 - accuracy: 0.2857
# Epoch 10/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3275 - accuracy: 0.4286
# Epoch 11/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3415 - accuracy: 0.5714
# Epoch 12/200
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3567 - accuracy: 0.2857
# Epoch 13/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3021 - accuracy: 0.3571
# Epoch 14/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2922 - accuracy: 0.5000
# Epoch 15/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3337 - accuracy: 0.2857
# Epoch 16/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3045 - accuracy: 0.4286
# Epoch 17/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2970 - accuracy: 0.5000
# Epoch 18/200
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2932 - accuracy: 0.3571
# Epoch 19/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2673 - accuracy: 0.4286
# Epoch 20/200
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2393 - accuracy: 0.4286
# Epoch 21/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2823 - accuracy: 0.3571
# Epoch 22/200
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2633 - accuracy: 0.2857
# Epoch 23/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2169 - accuracy: 0.5714
# Epoch 24/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1840 - accuracy: 0.7143
# Epoch 25/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1724 - accuracy: 0.5714
# Epoch 26/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1861 - accuracy: 0.6429
# Epoch 27/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2409 - accuracy: 0.5714
# Epoch 28/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1603 - accuracy: 0.7857
# Epoch 29/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.1263 - accuracy: 0.4286
# Epoch 30/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1140 - accuracy: 0.6429
# Epoch 31/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1318 - accuracy: 0.6429
# Epoch 32/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2006 - accuracy: 0.5000
# Epoch 33/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2376 - accuracy: 0.4286
# Epoch 34/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0609 - accuracy: 0.7857
# Epoch 35/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1078 - accuracy: 0.5000
# Epoch 36/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1393 - accuracy: 0.5000
# Epoch 37/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1387 - accuracy: 0.5000
# Epoch 38/200
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1486 - accuracy: 0.5714
# Epoch 39/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0252 - accuracy: 0.6429
# Epoch 40/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9062 - accuracy: 0.6429
# Epoch 41/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0581 - accuracy: 0.7143
# Epoch 42/200
# 3/3 [==============================] - 0s 3ms/step - loss: 1.0638 - accuracy: 0.6429
# Epoch 43/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9604 - accuracy: 0.5714
# Epoch 44/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9251 - accuracy: 0.7143
# Epoch 45/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8930 - accuracy: 0.7143
# Epoch 46/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0662 - accuracy: 0.4286
# Epoch 47/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9638 - accuracy: 0.5000
# Epoch 48/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9366 - accuracy: 0.5714
# Epoch 49/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0231 - accuracy: 0.4286
# Epoch 50/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9608 - accuracy: 0.6429
# Epoch 51/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8841 - accuracy: 0.6429
# Epoch 52/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9577 - accuracy: 0.4286
# Epoch 53/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9553 - accuracy: 0.5714
# Epoch 54/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8496 - accuracy: 0.7143
# Epoch 55/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9140 - accuracy: 0.7143
# Epoch 56/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8034 - accuracy: 0.5714
# Epoch 57/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8251 - accuracy: 0.7143
# Epoch 58/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8867 - accuracy: 0.3571
# Epoch 59/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9448 - accuracy: 0.5000
# Epoch 60/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7525 - accuracy: 0.7143
# Epoch 61/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8273 - accuracy: 0.6429
# Epoch 62/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8263 - accuracy: 0.5714
# Epoch 63/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8440 - accuracy: 0.6429
# Epoch 64/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7370 - accuracy: 0.7857
# Epoch 65/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8382 - accuracy: 0.6429
# Epoch 66/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7735 - accuracy: 0.5714
# Epoch 67/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8177 - accuracy: 0.7143
# Epoch 68/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8309 - accuracy: 0.7143
# Epoch 69/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7773 - accuracy: 0.5714
# Epoch 70/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7512 - accuracy: 0.7857
# Epoch 71/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8144 - accuracy: 0.5714
# Epoch 72/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8369 - accuracy: 0.5000
# Epoch 73/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 0.6429
# Epoch 74/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7339 - accuracy: 0.7857
# Epoch 75/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7408 - accuracy: 0.7143
# Epoch 76/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7499 - accuracy: 0.6429
# Epoch 77/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7398 - accuracy: 0.5714
# Epoch 78/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7758 - accuracy: 0.4286
# Epoch 79/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7296 - accuracy: 0.6429
# Epoch 80/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6953 - accuracy: 0.7857
# Epoch 81/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7445 - accuracy: 0.6429
# Epoch 82/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7956 - accuracy: 0.7143
# Epoch 83/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6518 - accuracy: 0.7143
# Epoch 84/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8012 - accuracy: 0.6429
# Epoch 85/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6880 - accuracy: 0.7143
# Epoch 86/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7879 - accuracy: 0.5000
# Epoch 87/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7164 - accuracy: 0.7857
# Epoch 88/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7858 - accuracy: 0.5000
# Epoch 89/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6298 - accuracy: 0.7143
# Epoch 90/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6854 - accuracy: 0.6429
# Epoch 91/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7174 - accuracy: 0.6429
# Epoch 92/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8024 - accuracy: 0.5000
# Epoch 93/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7132 - accuracy: 0.5000
# Epoch 94/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7430 - accuracy: 0.6429
# Epoch 95/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 0.6429
# Epoch 96/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7876 - accuracy: 0.7143
# Epoch 97/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6294 - accuracy: 0.6429
# Epoch 98/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7197 - accuracy: 0.5714
# Epoch 99/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7389 - accuracy: 0.6429
# Epoch 100/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7227 - accuracy: 0.7857
# Epoch 101/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6569 - accuracy: 0.5714
# Epoch 102/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6834 - accuracy: 0.7857
# Epoch 103/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7303 - accuracy: 0.4286
# Epoch 104/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7338 - accuracy: 0.5714
# Epoch 105/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7211 - accuracy: 0.5714
# Epoch 106/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7575 - accuracy: 0.6429
# Epoch 107/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6844 - accuracy: 0.5714
# Epoch 108/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7568 - accuracy: 0.5714
# Epoch 109/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6005 - accuracy: 0.5714
# Epoch 110/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6467 - accuracy: 0.5714
# Epoch 111/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6501 - accuracy: 0.7857
# Epoch 112/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7047 - accuracy: 0.5714
# Epoch 113/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7481 - accuracy: 0.5714
# Epoch 114/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6842 - accuracy: 0.7857
# Epoch 115/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6582 - accuracy: 0.6429
# Epoch 116/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6587 - accuracy: 0.5000
# Epoch 117/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7699 - accuracy: 0.6429
# Epoch 118/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6624 - accuracy: 0.5714
# Epoch 119/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5695 - accuracy: 0.6429
# Epoch 120/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5899 - accuracy: 0.6429
# Epoch 121/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6563 - accuracy: 0.5714
# Epoch 122/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7087 - accuracy: 0.6429
# Epoch 123/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6534 - accuracy: 0.7857
# Epoch 124/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6294 - accuracy: 0.6429
# Epoch 125/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6589 - accuracy: 0.5714
# Epoch 126/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7486 - accuracy: 0.5714
# Epoch 127/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7102 - accuracy: 0.7143
# Epoch 128/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6428 - accuracy: 0.5714
# Epoch 129/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7059 - accuracy: 0.5000
# Epoch 130/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.5714
# Epoch 131/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6967 - accuracy: 0.7143
# Epoch 132/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6729 - accuracy: 0.4286
# Epoch 133/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6559 - accuracy: 0.7857
# Epoch 134/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6661 - accuracy: 0.5000
# Epoch 135/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6761 - accuracy: 0.5714
# Epoch 136/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6042 - accuracy: 0.8571
# Epoch 137/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6205 - accuracy: 0.7143
# Epoch 138/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5732 - accuracy: 0.8571
# Epoch 139/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6574 - accuracy: 0.5714
# Epoch 140/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6775 - accuracy: 0.7143
# Epoch 141/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5902 - accuracy: 0.6429
# Epoch 142/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7282 - accuracy: 0.5714
# Epoch 143/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8371 - accuracy: 0.5000
# Epoch 144/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.6429
# Epoch 145/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6758 - accuracy: 0.5714
# Epoch 146/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6981 - accuracy: 0.4286
# Epoch 147/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5943 - accuracy: 0.7143
# Epoch 148/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7020 - accuracy: 0.7857
# Epoch 149/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7281 - accuracy: 0.6429
# Epoch 150/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6424 - accuracy: 0.5714
# Epoch 151/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6747 - accuracy: 0.5714
# Epoch 152/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6953 - accuracy: 0.5714
# Epoch 153/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6910 - accuracy: 0.5714
# Epoch 154/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6163 - accuracy: 0.7143
# Epoch 155/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6495 - accuracy: 0.6429
# Epoch 156/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6568 - accuracy: 0.5000
# Epoch 157/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6077 - accuracy: 0.6429
# Epoch 158/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6552 - accuracy: 0.6429
# Epoch 159/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7084 - accuracy: 0.6429
# Epoch 160/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6126 - accuracy: 0.7143
# Epoch 161/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7533 - accuracy: 0.5000
# Epoch 162/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6671 - accuracy: 0.8571
# Epoch 163/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7753 - accuracy: 0.5714
# Epoch 164/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6891 - accuracy: 0.7857
# Epoch 165/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7398 - accuracy: 0.7143
# Epoch 166/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6011 - accuracy: 0.5714
# Epoch 167/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6921 - accuracy: 0.7857
# Epoch 168/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6298 - accuracy: 0.7143
# Epoch 169/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6347 - accuracy: 0.6429
# Epoch 170/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.8571
# Epoch 171/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6483 - accuracy: 0.5714
# Epoch 172/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6727 - accuracy: 0.6429
# Epoch 173/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7128 - accuracy: 0.5000
# Epoch 174/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6108 - accuracy: 0.7857
# Epoch 175/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5628 - accuracy: 0.7857
# Epoch 176/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6398 - accuracy: 0.7143
# Epoch 177/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6863 - accuracy: 0.6429
# Epoch 178/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6780 - accuracy: 0.5714
# Epoch 179/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6851 - accuracy: 0.6429
# Epoch 180/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6560 - accuracy: 0.6429
# Epoch 181/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6319 - accuracy: 0.7857
# Epoch 182/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6321 - accuracy: 0.5714
# Epoch 183/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6549 - accuracy: 0.5714
# Epoch 184/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6584 - accuracy: 0.5714
# Epoch 185/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7869 - accuracy: 0.5000
# Epoch 186/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6443 - accuracy: 0.8571
# Epoch 187/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6179 - accuracy: 0.6429
# Epoch 188/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7108 - accuracy: 0.5714
# Epoch 189/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7083 - accuracy: 0.5000
# Epoch 190/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5722 - accuracy: 0.7857
# Epoch 191/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7245 - accuracy: 0.7143
# Epoch 192/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6025 - accuracy: 0.7857
# Epoch 193/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5842 - accuracy: 0.5714
# Epoch 194/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6147 - accuracy: 0.5714
# Epoch 195/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6374 - accuracy: 0.7143
# Epoch 196/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6556 - accuracy: 0.7143
# Epoch 197/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6865 - accuracy: 0.7143
# Epoch 198/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5856 - accuracy: 0.7143
# Epoch 199/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6638 - accuracy: 0.5714
# Epoch 200/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6192 - accuracy: 0.6429
# model created
# C:\Users\thaha\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('query.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

product_data=[]

with open('books_from_ecom.csv', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        product_data.append(row)

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model, k=1):
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    results = [(i, r) for i, r in enumerate(res)]
    results.sort(key=lambda x: x[1], reverse=True)
    
    # Return the top-k intents with their probabilities
    return_list = [{"intent": classes[i], "probability": str(r)} for i, r in results[:k]]
    print(return_list)
    return return_list




# def predict_class(sentence, model):
#     p = bow(sentence, words, show_details=False)
#     res = model.predict(np.array([p]))[0]
#     ERROR_THRESHOLD = 0.25
#     results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
#     results.sort(key=lambda x: x[1], reverse=True)
#     return_list = []
#     for r in results:
#         return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
#     return return_list

# %%
# def getResponse(intents, intents_json, user_query, product_data):
#     tag = intents[0]['intent']
#     list_of_intents = intents_json['intents']
#     for i in list_of_intents:
#         if i['tag'] == tag:
#             result = random.choice(i['response_templates'])
#             break

#     if "{product_name}" in result:
#         matching_product = None
#         product_name = None
#         for product in product_data:
#             if product['product_name'].lower() in user_query.lower():
#                 matching_product = product
#                 product_name = product['product_name']
#                 break

#         if matching_product:
#             response = f"{matching_product['product_name']} is a {matching_product['type']}. " \
#                        f"It's priced at {matching_product['product_real_price']} and currently in stock."
#             return response + "\nDo you have any more questions?"
#         else:
#             return "I'm sorry, but I couldn't find the product you're looking for."
#     elif "{author}" in result:
#         matching_author = None
#         author = None
#         for auth in product_data:
#             if product['author'].lower() in user_query.lower():
#                 matching_author = auth
#                 author = product['author']
#                 break

#         if matching_author:
#             response = "\n".join([f"Author: {book['author']}, Book: {book['product_name']}, Price: {book['product_real_price']}" for book in books_by_author])
#             return response + "\nDo you have any more questions?"
#         else:
#             return f"Sorry, no books found by {author_query}."
#     else:
#         return result





def getResponse(intents, intents_json, user_query, product_data):
    # Initialize variables to store result and matching intent
    result = None
    matching_intent = None
    
    # Loop through the intents in intents_json
    for intent in intents_json['intents']:
        # Get the tag of the current intent
        current_tag = intent['tag']
        
        # Check if the current_tag matches the predicted intent
        if current_tag in [i['intent'] for i in intents]:
            # Set matching_intent to the current intent
            matching_intent = intent
            break

    if matching_intent:
        # Get a random response template from the matching_intent
        result = random.choice(matching_intent['response_templates'])
    
    if result:
        if "{product_name}" in result:
            matching_product = None
            product_name = None
            for product in product_data:
                if product['product_name'].lower() in user_query.lower():
                    matching_product = product
                    product_name = product['product_name']
                    break

            if matching_product:
                response = f"{matching_product['product_name']} is a {matching_product['type']}. " \
                           f"It's priced at {matching_product['product_real_price']} and currently in stock."
                return response + "\nDo you have any more questions?"
            else:
                return "I'm sorry, but I couldn't find the product you're looking for."
        elif "{author}" in result:
            matching_author = None
            author = None
            for auth in product_data:
                if auth['author'].lower() in user_query.lower():
                    matching_author = auth
                    author = auth['author']
                    break

            if matching_author:
                author_books = "\n".join([f"Author: {book['author']}, Book: {book['product_name']}, Price: {book['product_real_price']}" for book in books_by_author])
                return author_books + "\nDo you have any more questions?"
            else:
                return f"Sorry, no books found by {author_query}."
    else:
        return "I'm not sure how to respond to that."

# %%
# def chatbot_response(text):
#     ints = predict_class(text, model)
#     res = getResponse(ints, intents,product_data,text)
#     return res


def chatbot_response(user_query):
    ints = predict_class(user_query, model)
    if user_query.lower() != 'no':
        if user_query.lower() != 'yes':
            res = getResponse(ints, intents, user_query,product_data)
        else:
            res = "What is your next question?"
    else:
        res = "Good bye! Have a nice day!"
    return res

# %% [markdown]
# ## GUI Interface

# %%
import tkinter
from tkinter import *

BG_GRAY = "#ABB2B9"
BG_COLOR = "#c5f0e3"
TEXT_COLOR = "#000000"

FONT = "Helvetica 14"
FONT_BOLD = "Helvetica 13 bold"


def send(event=None):
    msg = EntryBox.get("1.0", 'end-1c').strip()
    EntryBox.delete("0.0", END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#000000", font=("Verdana", 12))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("E-Commerce Chatbot")
base.resizable(width=FALSE, height=FALSE)
base.configure(width=800, height=800, bg=BG_COLOR)

ChatLog = Text(base, bd=0, bg=BG_COLOR, fg=TEXT_COLOR, font=FONT_BOLD)
ChatLog.config(state=DISABLED)

head_label = Label(base, bg=BG_COLOR, fg=TEXT_COLOR, text="Welcome to E-Commerce Chatbot", font=FONT_BOLD, pady=10)
head_label.place(relwidth=1)

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
ChatLog.focus()

SendButton = Button(base, font=("Verdana", 12, 'bold'), text="Send", width="12", height=15,
                    bd=0, bg="#ed9061", activebackground="#3c9d9b", fg='#ffffff',
                    command=send)

EntryBox = Text(base, bg="white", width="29", height="5", font="Arial", background="#dddddd")
EntryBox.focus()
EntryBox.bind("<Return>", send)  # Bind Enter key to send function

scrollbar.place(x=775, y=6, height=800)
ChatLog.place(x=5, y=40, height=700, width=770)
EntryBox.place(x=0, y=740, height=60, width=600)
SendButton.place(x=600, y=740, height=60, width=175)

# %%
base.mainloop()
